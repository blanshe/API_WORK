# %%
statistics.median([1, 10, 12])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-f6086704b681> in <module>
# ----> 1 statistics.median([1, 10, 12])
#
# NameError: name 'statistics' is not defined

# %%
#!pip install python-dotenv

# %%
# !touch .env
# Out:
# STACK_API_KEY='DWTD*S3wc0Q8DjPaMEqS1A(('

# %%
# You need a .env file with variables in it
import os

# %load_ext dotenv
# %dotenv
# Out:
# The dotenv extension is already loaded. To reload it, use:
#   %reload_ext dotenv

# %%
os.getenv('STACK_API_KEY')
# Out:
# 'DWTD*S3wc0Q8DjPaMEqS1A(('

# %%
# !source .env

# %%
import os

# %%
os.environ['STACK_API_KEY']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-2fa2293937ad> in <module>
# ----> 1 os.environ['STACK_API_KEY']
#
# ~/.pyenv/versions/3.6.7/lib/python3.6/os.py in __getitem__(self, key)
#     667         except KeyError:
#     668             # raise KeyError with the original key value
# --> 669             raise KeyError(key) from None
#     670         return self.decodevalue(value)
#     671
#
# KeyError: 'STACK_API_KEY'

# %%
from stackapi import StackAPI
SITE = StackAPI('stackoverflow', key='DWTD*S3wc0Q8DjPaMEqS1A((')

# %%
comments = SITE.fetch('comments')

# %%
comments.keys()
# Out:
# dict_keys(['backoff', 'has_more', 'page', 'quota_max', 'quota_remaining', 'total', 'items'])

# %%
comments['total']
# Out:
# 0

# %%
comments['has_more']
# Out:
# True

# %%
comments

# %%
questions = SITE.fetch('questions', tagged='python', sort='creation')

# %%
questions
# Out:
# {'backoff': 0,
#  'has_more': True,
#  'page': 5,
#  'quota_max': 300,
#  'quota_remaining': 300,
#  'total': 0,
#  'items': [{'tags': ['python', 'flask'],
#    'owner': {'reputation': 1,
#     'user_id': 8713949,
#     'user_type': 'registered',
#     'profile_image': 'https://i.stack.imgur.com/vScfx.jpg?s=128&g=1',
#     'display_name': 'K-K',
#     'link': 'https://stackoverflow.com/users/8713949/k-k'},
#    'is_answered': False,
#    'view_count': 2,
#    'answer_count': 0,
#    'score': 0,
#    'last_activity_date': 1559785471,
#    'creation_date': 1559785471,
#    'question_id': 56469974,
#    'link': 'https://stackoverflow.com/questions/56469974/getting-a-recursionerror-maximum-recursion-depth-exceeded-while-calling-a-pytho',
#    'title': 'Getting a RecursionError: maximum recursion depth exceeded while calling a Python object when running my flask app'},
#   {'tags': ['python', 'jython'],
#    'owner': {'reputation': 20,
#     'user_id': 9968765,
# ...

# %%
import dateutil

# %%
d = dateutil.parser.parse("January 2, 1970")

# %%
int(d.strftime('%ms'))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-687fe00db39f> in <module>
# ----> 1 int(d.strftime('%ms'))
#
# ValueError: invalid literal for int() with base 10: '01s'

# %%
import datetime

# %%
datetime.datetime(2012,4,1,0,0).timestamp()
# Out:
# 1333252800.0

# %%
d.timestamp() * 1000
# Out:
# 104400000.0

# %%
dateutil.parser.parse("January 1, 1970").timestamp()
# Out:
# 18000.0

# %%
datetime.datetime(2012,4,1,0,0).timestamp()
# Out:
# 1333252800.0

# %%
import datetime

# %%
datetime.datetime.fromtimestamp(1333252800)
# Out:
# datetime.datetime(2012, 4, 1, 0, 0)

# %%
datetime.datetime.fromtimestamp(0)
# Out:
# datetime.datetime(1969, 12, 31, 19, 0)
